# %% [markdown]
# <a href="https://colab.research.google.com/github/jsoook-dt/python-colab-analysis-study/blob/yoonju/Project01_Yoonju_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Marketing Campaign Analysis**

# %%
import pandas as pd
import kagglehub


path = kagglehub.dataset_download("manishabhatt22/marketing-campaign-performance-dataset")
print("Dataset path:", path)

#importing data
df = pd.read_csv(f"{path}/marketing_campaign_dataset.csv")
print("Data Sample:")
display(df.head())

#data types check
print("\nData Information:")
df.info()
# Out:
# ...
# 100%|██████████| 5.02M/5.02M [00:00<00:00, 127MB/s]
# Extracting files...
# Dataset path: /root/.cache/kagglehub/datasets/manishabhatt22/marketing-campaign-performance-dataset/versions/1
# Data Sample:
#    Campaign_ID              Company Campaign_Type Target_Audience Duration  \
# 0            1  Innovate Industries         Email       Men 18-24  30 days
# 1            2       NexGen Systems         Email     Women 35-44  60 days
# 2            3    Alpha Innovations    Influencer       Men 25-34  30 days
# 3            4   DataTech Solutions       Display        All Ages  60 days
# 4            5       NexGen Systems         Email       Men 25-34  15 days
#
#   Channel_Used  Conversion_Rate Acquisition_Cost   ROI     Location  Language  \
# 0   Google Ads             0.04       $16,174.00  6.29      Chicago   Spanish
# 1   Google Ads             0.12       $11,566.00  5.61     New York    German
# 2      YouTube             0.07       $10,200.00  7.18  Los Angeles    French
# ...

# %% [markdown]
# ## **Data Cleaning: Analysing individual columns & fixing data types**

# %% [markdown]
# **Acquisition cost**

# %%
df["Acquisition_Cost"] = (
    df["Acquisition_Cost"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float)
)

df["Acquisition_Cost"].value_counts()
# Out:
# Acquisition_Cost
# 16578.0    32
# 6570.0     31
# 9128.0     30
# 8503.0     29
# 15430.0    29
#            ..
# 7917.0      3
# 7878.0      3
# 7443.0      3
# 14068.0     2
# 9623.0      2
# Name: count, Length: 15001, dtype: int64

# %% [markdown]
# **Duration**

# %%
df["Duration"] = df["Duration"].str.replace(" days", "", regex=False).astype(int)
df["Duration"].value_counts()
# Out:
# Duration
# 30    50255
# 45    50100
# 60    49866
# 15    49779
# Name: count, dtype: int64

# %% [markdown]
# **Date**

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Date"].head()
# Out:
# 0   2021-01-01
# 1   2021-01-02
# 2   2021-01-03
# 3   2021-01-04
# 4   2021-01-05
# Name: Date, dtype: datetime64[ns]

# %%
df["Company"].value_counts()
# Out:
# Company
# TechCorp               40237
# Alpha Innovations      40051
# DataTech Solutions     40012
# NexGen Systems         39991
# Innovate Industries    39709
# Name: count, dtype: int64

# %%
df["Campaign_Type"].value_counts()
# Out:
# Campaign_Type
# Influencer      40169
# Search          40157
# Display         39987
# Email           39870
# Social Media    39817
# Name: count, dtype: int64

# %%
df["Target_Audience"].value_counts()
# Out:
# Target_Audience
# Men 18-24      40258
# Men 25-34      40023
# All Ages       40019
# Women 25-34    40013
# Women 35-44    39687
# Name: count, dtype: int64

# %%
df["Channel_Used"].value_counts()
# Out:
# Channel_Used
# Email         33599
# Google Ads    33438
# YouTube       33392
# Instagram     33392
# Website       33360
# Facebook      32819
# Name: count, dtype: int64

# %%
df["Location"].value_counts()
# Out:
# Location
# Miami          40269
# New York       40024
# Chicago        40010
# Los Angeles    39947
# Houston        39750
# Name: count, dtype: int64

# %%
df["Language"].value_counts()
# Out:
# Language
# Mandarin    40255
# Spanish     40102
# German      39983
# English     39896
# French      39764
# Name: count, dtype: int64

# %%
df["Customer_Segment"].value_counts()
# Out:
# Customer_Segment
# Foodies                40208
# Tech Enthusiasts       40151
# Outdoor Adventurers    40011
# Health & Wellness      39888
# Fashionistas           39742
# Name: count, dtype: int64

# %% [markdown]
# **Data cleaning is done, reviewing the cleaned data**

# %%
df.head()
# Out:
#    Campaign_ID              Company Campaign_Type Target_Audience  Duration  \
# 0            1  Innovate Industries         Email       Men 18-24        30
# 1            2       NexGen Systems         Email     Women 35-44        60
# 2            3    Alpha Innovations    Influencer       Men 25-34        30
# 3            4   DataTech Solutions       Display        All Ages        60
# 4            5       NexGen Systems         Email       Men 25-34        15
#
#   Channel_Used  Conversion_Rate  Acquisition_Cost   ROI     Location  \
# 0   Google Ads             0.04           16174.0  6.29      Chicago
# 1   Google Ads             0.12           11566.0  5.61     New York
# 2      YouTube             0.07           10200.0  7.18  Los Angeles
# 3      YouTube             0.11           12724.0  5.55        Miami
# 4      YouTube             0.05           16452.0  6.50  Los Angeles
#
#    Language  Clicks  Impressions  Engagement_Score     Customer_Segment  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Campaign_ID       200000 non-null  int64
#  1   Company           200000 non-null  object
#  2   Campaign_Type     200000 non-null  object
#  3   Target_Audience   200000 non-null  object
#  4   Duration          200000 non-null  int64
#  5   Channel_Used      200000 non-null  object
#  6   Conversion_Rate   200000 non-null  float64
#  7   Acquisition_Cost  200000 non-null  float64
#  8   ROI               200000 non-null  float64
#  9   Location          200000 non-null  object
#  10  Language          200000 non-null  object
#  11  Clicks            200000 non-null  int64
#  12  Impressions       200000 non-null  int64
#  13  Engagement_Score  200000 non-null  int64
#  14  Customer_Segment  200000 non-null  object
# ...

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# **ROI efficiency by Channel**

# %%
roi_df = df.groupby("Channel_Used")["ROI"].mean().reset_index()
roi_df = roi_df.sort_values(by="ROI", ascending=False).round(2)
roi_df
# Out:
#   Channel_Used   ROI
# 1     Facebook  5.02
# 4      Website  5.01
# 2   Google Ads  5.00
# 0        Email  5.00
# 5      YouTube  4.99
# 3    Instagram  4.99

# %% [markdown]
# **Conversion Rate by Campaign Type**

# %%
conversion_df = df.groupby("Campaign_Type")["Conversion_Rate"].mean().reset_index()
conversion_df = conversion_df.sort_values(by="Conversion_Rate", ascending=False)
conversion_df
# Out:
#   Campaign_Type  Conversion_Rate
# 2    Influencer         0.080315
# 4  Social Media         0.080135
# 0       Display         0.080089
# 3        Search         0.080021
# 1         Email         0.079788

# %% [markdown]
# **ROI VS Conversion**

# %%
conversion_roi_df = (
    df.groupby("Campaign_Type")
      .agg(
          Conversion_Rate=("Conversion_Rate", "mean"),
          ROI=("ROI", "mean")
      )
      .reset_index()
)

conversion_roi_df
# Out:
#   Campaign_Type  Conversion_Rate       ROI
# 0       Display         0.080089  5.006551
# 1         Email         0.079788  4.994295
# 2    Influencer         0.080315  5.011068
# 3        Search         0.080021  5.008357
# 4  Social Media         0.080135  4.991784

# %%
duration_df = df.groupby("Duration")["ROI"].mean().reset_index()
duration_df = duration_df.sort_values(by="ROI", ascending=False)

duration_df
# Out:
#    Duration       ROI
# 1        30  5.008887
# 3        60  5.006480
# 2        45  4.997627
# 0        15  4.996720

# %% [markdown]
# **ROI by Target Audience**

# %%
audience_df = df.groupby("Target_Audience")["ROI"].mean().reset_index()
audience_df = audience_df.sort_values(by="ROI", ascending=False)

audience_df
# Out:
#   Target_Audience       ROI
# 2       Men 25-34  5.020627
# 4     Women 35-44  5.006330
# 0        All Ages  5.005174
# 3     Women 25-34  4.997351
# 1       Men 18-24  4.982853

# %% [markdown]
# **Channel Performance by Target Audience**

# %%
aud_ch_df = (
    df.groupby(["Target_Audience", "Channel_Used"])
      .agg(
          ROI=("ROI", "mean"),
          Conversion=("Conversion_Rate", "mean"),
          Count=("ROI", "count")
      )
      .reset_index()
)

aud_ch_df = aud_ch_df.sort_values(by=["ROI", "Conversion"], ascending=[False, False])

aud_ch_df
# Out:
#    Target_Audience Channel_Used       ROI  Conversion  Count
# 13       Men 25-34     Facebook  5.058776    0.080112   6365
# 16       Men 25-34      Website  5.038518    0.080027   6743
# 25     Women 35-44     Facebook  5.033879    0.080048   6476
# 1         All Ages     Facebook  5.033015    0.079518   6617
# 14       Men 25-34   Google Ads  5.030664    0.080721   6807
# 4         All Ages      Website  5.027339    0.080339   6645
# 2         All Ages   Google Ads  5.022231    0.080485   6674
# 24     Women 35-44        Email  5.014520    0.080961   6719
# 19     Women 25-34     Facebook  5.010939    0.079748   6634
# 29     Women 35-44      YouTube  5.009632    0.080029   6596
# 18     Women 25-34        Email  5.009611    0.079923   6653
# 8        Men 18-24   Google Ads  5.009151    0.080054   6658
# 28     Women 35-44      Website  5.007805    0.079960   6561
# 12       Men 25-34        Email  5.007358    0.080458   6700
# ...

# %% [markdown]
# **ROI by Location & language**

# %%
loc_lan_df = (
    df.groupby(["Location", "Language"])["ROI"]
      .mean()
      .reset_index()
)

loc_lan_df = loc_lan_df.sort_values(by="ROI", ascending=False)

loc_lan_df
# Out:
#        Location  Language       ROI
# 1       Chicago    French  5.045077
# 13  Los Angeles  Mandarin  5.031411
# 19        Miami   Spanish  5.028071
# 7       Houston    German  5.024291
# 11  Los Angeles    French  5.023914
# 16        Miami    French  5.017525
# 12  Los Angeles    German  5.017423
# 18        Miami  Mandarin  5.011864
# 8       Houston  Mandarin  5.010827
# 15        Miami   English  5.005725
# 5       Houston   English  5.002508
# 24     New York   Spanish  5.000856
# 6       Houston    French  5.000504
# 17        Miami    German  4.998350
# 9       Houston   Spanish  4.997881
# 3       Chicago  Mandarin  4.995719
# 4       Chicago   Spanish  4.995625
# 10  Los Angeles   English  4.994862
# 0       Chicago   English  4.987194
# 23     New York  Mandarin  4.986262
# 14  Los Angeles   Spanish  4.986205
# 2       Chicago    German  4.985008
# 22     New York    German  4.980121
# 21     New York    French  4.970030
# 20     New York   English  4.963692

# %% [markdown]
# **ROI by Customer Segment**

# %%
segmentation_df = df.groupby("Customer_Segment")["ROI"].mean().reset_index()
segmentation_df = segmentation_df.sort_values(by="ROI", ascending=False)

segmentation_df
# Out:
#       Customer_Segment       ROI
# 1              Foodies  5.004376
# 4     Tech Enthusiasts  5.004234
# 2    Health & Wellness  5.003202
# 0         Fashionistas  5.000962
# 3  Outdoor Adventurers  4.999393
